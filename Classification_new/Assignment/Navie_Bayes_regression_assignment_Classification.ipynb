# %%
import pandas as pd
data=pd.read_csv('CKD.csv')

# %%
datanew=pd.get_dummies(data,drop_first=True)

# %%
datanew
# Out:
#            age         bp   al   su         bgr          bu        sc  \
# 0     2.000000  76.459948  3.0  0.0  148.112676   57.482105  3.077356
# 1     3.000000  76.459948  2.0  0.0  148.112676   22.000000  0.700000
# 2     4.000000  76.459948  1.0  0.0   99.000000   23.000000  0.600000
# 3     5.000000  76.459948  1.0  0.0  148.112676   16.000000  0.700000
# 4     5.000000  50.000000  0.0  0.0  148.112676   25.000000  0.600000
# ..         ...        ...  ...  ...         ...         ...       ...
# 394  51.492308  70.000000  0.0  0.0  219.000000   36.000000  1.300000
# 395  51.492308  70.000000  0.0  2.0  220.000000   68.000000  2.800000
# 396  51.492308  70.000000  3.0  0.0  110.000000  115.000000  6.000000
# 397  51.492308  90.000000  0.0  0.0  207.000000   80.000000  6.800000
# 398  51.492308  80.000000  0.0  0.0  100.000000   49.000000  1.000000
#
#             sod       pot       hrmo  ...  pc_normal  pcc_present  ba_present  \
# ...

# %%
datanew.columns
# Out:
# Index(['age', 'bp', 'al', 'su', 'bgr', 'bu', 'sc', 'sod', 'pot', 'hrmo', 'pcv',
#        'wc', 'rc', 'sg_b', 'sg_c', 'sg_d', 'sg_e', 'rbc_normal', 'pc_normal',
#        'pcc_present', 'ba_present', 'htn_yes', 'dm_yes', 'cad_yes',
#        'appet_yes', 'pe_yes', 'ane_yes', 'classification_yes'],
#       dtype='object')

# %%
independand=datanew[['age', 'bp', 'al', 'su', 'bgr', 'bu', 'sc', 'sod', 'pot', 'hrmo', 'pcv',
       'wc', 'rc', 'sg_b', 'sg_c', 'sg_d', 'sg_e', 'rbc_normal', 'pc_normal',
       'pcc_present', 'ba_present', 'htn_yes', 'dm_yes', 'cad_yes',
       'appet_yes', 'pe_yes', 'ane_yes']]

# %%
dependand=datanew[['classification_yes']]

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(independand,dependand,test_size=1/3,random_state=0)

# %%
# # weights{‘uniform’, ‘distance’},algorithm{‘auto’, ‘ball_tree’, ‘kd_tree’, ‘brute’},n_neighbors=5
# from sklearn.model_selection import GridSearchCV
# from sklearn.naive_bayes import BernoulliNB
# param_grid = {}

# grid=GridSearchCV(BernoulliNB(), params_grid, refit=True, verbose=3, n_jobs=-1,scoring='f1_weighted')
# grid.fit(X_train,Y_train)

# %%
# from sklearn.model_selection import GridSearchCV
# from sklearn.naive_bayes import MultinomialNB
# param_grid = {}

# grid=GridSearchCV(MultinomialNB(), params_grid, refit=True, verbose=3, n_jobs=-1,scoring='f1_weighted')
# grid.fit(X_train,Y_train)

# %%
# from sklearn.model_selection import GridSearchCV
# from sklearn.naive_bayes import ComplementNB
# param_grid = {}

# grid=GridSearchCV(ComplementNB(), params_grid, refit=True, verbose=3, n_jobs=-1,scoring='f1_weighted')
# grid.fit(X_train,Y_train)

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.naive_bayes import GaussianNB
param_grid = {}

grid=GridSearchCV(GaussianNB(), params_grid, refit=True, verbose=3, n_jobs=-1,scoring='f1_weighted')
grid.fit(X_train,Y_train)
# Out:
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# C:\Users\mojayara\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1339: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# GridSearchCV(estimator=GaussianNB(), n_jobs=-1, param_grid={},
#              scoring='f1_weighted', verbose=3)

# %%
cv=grid.cv_results_
table=pd.DataFrame.from_dict(cv)

# %%
table
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time params  \
# 0       0.067799      0.018395         0.018529        0.002482     {}
#
#    split0_test_score  split1_test_score  split2_test_score  split3_test_score  \
# 0           0.981569           0.981014           0.981217                1.0
#
#    split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0           0.981217         0.985003          0.0075                1

# %%
grid.best_params_
# Out:
# {}

# %%
grid.best_score_
# Out:
# 0.9850034030491555

# %%
y_predict=grid.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix
cm=confusion_matrix(Y_test,y_predict)
cm
# Out:
# array([[51,  0],
#        [ 3, 79]], dtype=int64)

# %%
from sklearn.metrics import classification_report
report=classification_report(Y_test,y_predict)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#        False       0.94      1.00      0.97        51
#         True       1.00      0.96      0.98        82
#
#     accuracy                           0.98       133
#    macro avg       0.97      0.98      0.98       133
# weighted avg       0.98      0.98      0.98       133

# %%
from sklearn.metrics import roc_auc_score
roc_auc_score(Y_test,grid.predict_proba(X_test)[:,-1])
# Out:
# 1.0
