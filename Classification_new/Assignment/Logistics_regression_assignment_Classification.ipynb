# %%
import pandas as pd
data=pd.read_csv('CKD.csv')

# %%
datanew=pd.get_dummies(data,drop_first=True)

# %%
datanew
# Out:
#            age         bp   al   su         bgr          bu        sc  \
# 0     2.000000  76.459948  3.0  0.0  148.112676   57.482105  3.077356
# 1     3.000000  76.459948  2.0  0.0  148.112676   22.000000  0.700000
# 2     4.000000  76.459948  1.0  0.0   99.000000   23.000000  0.600000
# 3     5.000000  76.459948  1.0  0.0  148.112676   16.000000  0.700000
# 4     5.000000  50.000000  0.0  0.0  148.112676   25.000000  0.600000
# ..         ...        ...  ...  ...         ...         ...       ...
# 394  51.492308  70.000000  0.0  0.0  219.000000   36.000000  1.300000
# 395  51.492308  70.000000  0.0  2.0  220.000000   68.000000  2.800000
# 396  51.492308  70.000000  3.0  0.0  110.000000  115.000000  6.000000
# 397  51.492308  90.000000  0.0  0.0  207.000000   80.000000  6.800000
# 398  51.492308  80.000000  0.0  0.0  100.000000   49.000000  1.000000
#
#             sod       pot       hrmo  ...  pc_normal  pcc_present  ba_present  \
# ...

# %%
datanew.columns
# Out:
# Index(['age', 'bp', 'al', 'su', 'bgr', 'bu', 'sc', 'sod', 'pot', 'hrmo', 'pcv',
#        'wc', 'rc', 'sg_b', 'sg_c', 'sg_d', 'sg_e', 'rbc_normal', 'pc_normal',
#        'pcc_present', 'ba_present', 'htn_yes', 'dm_yes', 'cad_yes',
#        'appet_yes', 'pe_yes', 'ane_yes', 'classification_yes'],
#       dtype='object')

# %%
independand=datanew[['age', 'bp', 'al', 'su', 'bgr', 'bu', 'sc', 'sod', 'pot', 'hrmo', 'pcv',
       'wc', 'rc', 'sg_b', 'sg_c', 'sg_d', 'sg_e', 'rbc_normal', 'pc_normal',
       'pcc_present', 'ba_present', 'htn_yes', 'dm_yes', 'cad_yes',
       'appet_yes', 'pe_yes', 'ane_yes']]

# %%
dependand=datanew[['classification_yes']]

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(independand,dependand,test_size=1/3,random_state=0)

# %%
# from sklearn.preprocessing import StandardScaler
# sc=StandardScaler()
# scTrain=sc.fit_transform(X_train)
# scTrest=sc.fit(X_test)

# %%
#penalty{‘l1’, ‘l2’, ‘elasticnet’, None},solver{‘lbfgs’, ‘liblinear’, ‘newton-cg’, ‘newton-cholesky’, ‘sag’, ‘saga’},multi_class{‘auto’, ‘ovr’, ‘multinomial’},C=1.0
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import LogisticRegression
params_grid=param_grid = {'penalty':['l1','l2','elasticnet','None'],
             'solver':['lbfgs','liblinear','newton-cg','newton-cholesky','sag','saga'],'multi_class':['auto','ovr','multinomial'],'C':[1.0,10,100]}
grid=GridSearchCV(LogisticRegression(), params_grid, refit=True, verbose=3, n_jobs=-1,scoring='f1_weighted')
grid.fit(X_train,Y_train)
# Out:
# Fitting 5 folds for each of 216 candidates, totalling 1080 fits
# C:\Users\mojayara\AppData\Local\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:540: FitFailedWarning:
# 765 fits failed out of a total of 1080.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 45 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\mojayara\AppData\Local\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 888, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\mojayara\AppData\Local\anaconda3\Lib\site-packages\sklearn\base.py", line 1473, in wrapper
#     return fit_method(estimator, *args, **kwargs)
# ...

# %%
cv=grid.cv_results_
table=pd.DataFrame.from_dict(cv)

# %%
table
# Out:
#      mean_fit_time  std_fit_time  mean_score_time  std_score_time  param_C  \
# 0         0.001356      0.000315          0.00000          0.0000      1.0
# 1         0.017130      0.005264          0.01464          0.0035      1.0
# 2         0.001466      0.000627          0.00000          0.0000      1.0
# 3         0.003319      0.001563          0.00000          0.0000      1.0
# 4         0.001857      0.000454          0.00000          0.0000      1.0
# ..             ...           ...              ...             ...      ...
# 211       0.001535      0.000452          0.00000          0.0000    100.0
# 212       0.001625      0.000514          0.00000          0.0000    100.0
# 213       0.001650      0.000536          0.00000          0.0000    100.0
# 214       0.001425      0.000527          0.00000          0.0000    100.0
# 215       0.001626      0.000455          0.00000          0.0000    100.0
#
#     param_multi_class param_penalty     param_solver  \
# ...

# %%
y_predict=grid.predict(X_test)

# %%
grid.best_params_
# Out:
# {'C': 1.0,
#  'multi_class': 'multinomial',
#  'penalty': 'l2',
#  'solver': 'newton-cg'}

# %%
from sklearn.metrics import confusion_matrix
cm=confusion_matrix(Y_test,y_predict)
cm
# Out:
# array([[50,  1],
#        [ 0, 82]], dtype=int64)

# %%
from sklearn.metrics import classification_report
report=classification_report(Y_test,y_predict)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#        False       1.00      0.98      0.99        51
#         True       0.99      1.00      0.99        82
#
#     accuracy                           0.99       133
#    macro avg       0.99      0.99      0.99       133
# weighted avg       0.99      0.99      0.99       133

# %%
from sklearn.metrics import roc_auc_score
roc_auc_score(Y_test,grid.predict_proba(X_test)[:,-1])
# Out:
# 1.0
