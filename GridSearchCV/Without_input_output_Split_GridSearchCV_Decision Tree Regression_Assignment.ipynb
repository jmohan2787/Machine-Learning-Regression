# %%
import pandas as pd

# %%
data=pd.read_csv('insurance_pre.csv')

# %%
data1=pd.get_dummies(data,drop_first=True)

# %%
data1
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400     False        True
# 1      18  33.770         1   1725.55230      True       False
# 2      28  33.000         3   4449.46200      True       False
# 3      33  22.705         0  21984.47061      True       False
# 4      32  28.880         0   3866.85520      True       False
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830      True       False
# 1334   18  31.920         0   2205.98080     False       False
# 1335   18  36.850         0   1629.83350     False       False
# 1336   21  25.800         0   2007.94500     False       False
# 1337   61  29.070         0  29141.36030     False        True
#
# [1338 rows x 6 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
data1.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
independend=data1[['age', 'bmi', 'children', 'sex_male', 'smoker_yes']]

# %%
dependend=data1[['charges']]

# %%
independend
# Out:
#       age     bmi  children  sex_male  smoker_yes
# 0      19  27.900         0     False        True
# 1      18  33.770         1      True       False
# 2      28  33.000         3      True       False
# 3      33  22.705         0      True       False
# 4      32  28.880         0      True       False
# ...   ...     ...       ...       ...         ...
# 1333   50  30.970         3      True       False
# 1334   18  31.920         0     False       False
# 1335   18  36.850         0     False       False
# 1336   21  25.800         0     False       False
# 1337   61  29.070         0     False        True
#
# [1338 rows x 5 columns]

# %%
dependend
# Out:
#           charges
# 0     16884.92400
# 1      1725.55230
# 2      4449.46200
# 3     21984.47061
# 4      3866.85520
# ...           ...
# 1333  10600.54830
# 1334   2205.98080
# 1335   1629.83350
# 1336   2007.94500
# 1337  29141.36030
#
# [1338 rows x 1 columns]

# %%
# X_train,X_test,Y_train,Y_test=train_test_split(independend,dependend,train_size=0.3,random_state=0)

# %%
# from sklearn.preprocessing import StandardScaler
# sc=StandardScaler()
# X_train_pre=sc.fit_transform(X_train)
# X_test_pre=sc.transform(X_test)

# %%
#criterion{“squared_error”, “friedman_mse”, “absolute_error”, “poisson”}, default=”squared_error”
#splitter{“best”, “random”}, default=”best”
#max_featuresint, float or {“sqrt”, “log2”}, default=None

from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import GridSearchCV
param={'criterion':['squared_error', 'friedman_mse', 'absolute_error', 'poisson'], 'splitter':['best', 'random'], 'max_features':['sqrt','log2']}
grid=GridSearchCV(DecisionTreeRegressor(),param,refit=True,verbose=3,n_jobs=-1)
# grid.fit(X_train_pre,Y_train)
grid.fit(independend,dependend)
# Out:
# Fitting 5 folds for each of 16 candidates, totalling 80 fits
# GridSearchCV(estimator=DecisionTreeRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['squared_error', 'friedman_mse',
#                                        'absolute_error', 'poisson'],
#                          'max_features': ['sqrt', 'log2'],
#                          'splitter': ['best', 'random']},
#              verbose=3)

# %%
re=grid.cv_results_

# %%
# from sklearn.metrics import r2_score
# y_prediction=grid.predict(X_test_pre)
# r_score=r2_score(Y_test,y_prediction)
# r_score

# %%
grid.best_score_
# Out:
# 0.6958173604725743

# %%
grid.best_params_
# Out:
# {'criterion': 'friedman_mse', 'max_features': 'log2', 'splitter': 'best'}

# %%
table=pd.DataFrame.from_dict(re)

# %%
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.005771      0.000394         0.002392        0.000489
# 1        0.005291      0.000942         0.003707        0.000732
# 2        0.005209      0.000380         0.003279        0.000472
# 3        0.008319      0.002601         0.001608        0.002408
# 4        0.007080      0.004060         0.001798        0.003597
# 5        0.001437      0.002874         0.008163        0.003202
# 6        0.008758      0.002026         0.001368        0.001884
# 7        0.001534      0.003067         0.007541        0.002513
# 8        0.023207      0.002860         0.002653        0.001215
# 9        0.017224      0.003164         0.002399        0.001200
# 10       0.016145      0.004856         0.004800        0.004946
# 11       0.014040      0.004662         0.002648        0.003973
# 12       0.005515      0.002399         0.003024        0.003716
# 13       0.007031      0.004090         0.002012        0.003781
# 14       0.005113      0.004457         0.002015        0.004031
# 15       0.003966      0.004862         0.004027        0.004735
#
#    param_criterion param_max_features param_splitter  \
# 0    squared_error               sqrt           best
# 1    squared_error               sqrt         random
# 2    squared_error               log2           best
# 3    squared_error               log2         random
# 4     friedman_mse               sqrt           best
# 5     friedman_mse               sqrt         random
# 6     friedman_mse               log2           best
# 7     friedman_mse               log2         random
# 8   absolute_error               sqrt           best
# 9   absolute_error               sqrt         random
# 10  absolute_error               log2           best
# 11  absolute_error               log2         random
# 12         poisson               sqrt           best
# 13         poisson               sqrt         random
# 14         poisson               log2           best
# 15         poisson               log2         random
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'squared_error', 'max_features':...           0.670173
# 1   {'criterion': 'squared_error', 'max_features':...           0.627079
# 2   {'criterion': 'squared_error', 'max_features':...           0.595004
# 3   {'criterion': 'squared_error', 'max_features':...           0.690898
# 4   {'criterion': 'friedman_mse', 'max_features': ...           0.616243
# 5   {'criterion': 'friedman_mse', 'max_features': ...           0.695986
# 6   {'criterion': 'friedman_mse', 'max_features': ...           0.746439
# 7   {'criterion': 'friedman_mse', 'max_features': ...           0.713304
# 8   {'criterion': 'absolute_error', 'max_features'...           0.686385
# 9   {'criterion': 'absolute_error', 'max_features'...           0.676119
# 10  {'criterion': 'absolute_error', 'max_features'...           0.630481
# 11  {'criterion': 'absolute_error', 'max_features'...           0.729059
# 12  {'criterion': 'poisson', 'max_features': 'sqrt...           0.517176
# 13  {'criterion': 'poisson', 'max_features': 'sqrt...           0.651577
# 14  {'criterion': 'poisson', 'max_features': 'log2...           0.718735
# 15  {'criterion': 'poisson', 'max_features': 'log2...           0.694754
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.630520           0.695907           0.768898
# 1            0.598927           0.561276           0.724378
# 2            0.618854           0.647746           0.466061
# 3            0.492450           0.748449           0.670328
# 4            0.655253           0.718732           0.714150
# 5            0.475045           0.658854           0.658202
# 6            0.655001           0.760376           0.690624
# 7            0.651152           0.509848           0.631267
# 8            0.552004           0.616663           0.690182
# 9            0.580009           0.628212           0.723278
# 10           0.588504           0.689982           0.734882
# 11           0.595423           0.659850           0.583176
# 12           0.638266           0.725172           0.682907
# 13           0.622514           0.714271           0.661689
# 14           0.581469           0.705890           0.701802
# 15           0.631499           0.671857           0.679122
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.701934         0.693486        0.045326                2
# 1            0.752800         0.652892        0.073572                7
# 2            0.660423         0.597618        0.069602               16
# 3            0.643061         0.649037        0.085608               11
# 4            0.600939         0.661063        0.048583                6
# 5            0.609119         0.619441        0.077294               15
# 6            0.626645         0.695817        0.051397                1
# 7            0.682584         0.637631        0.069712               13
# 8            0.673450         0.643737        0.052928               12
# 9            0.576203         0.636764        0.056560               14
# 10           0.611920         0.651154        0.053684                8
# 11           0.681847         0.649871        0.054416               10
# 12           0.688146         0.650333        0.072067                9
# 13           0.739678         0.677946        0.042808                4
# 14           0.702533         0.682086        0.050676                3
# 15           0.691560         0.673758        0.022698                5

# %%
age=float(input('Age:'))
bmi_input=float(input('BMI:'))
childeren=float(input('childeren:'))
sex=int(input('sex Male=0 or else'))
smoker=int(input('smoker Yes=0 else 1'))
# Out:
# Age: 23
# BMI: 43
# childeren: 2
# sex Male=0 or else 0
# smoker Yes=0 else 1 1

# %%
Future_predict=grid.predict([[age,bmi_input,childeren,sex,smoker]])
# Out:
# C:\Users\mojayara\AppData\Local\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(

# %%
print(Future_predict)
# Out:
# [40904.1995]
