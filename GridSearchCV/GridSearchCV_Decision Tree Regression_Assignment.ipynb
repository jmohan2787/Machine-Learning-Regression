# %%
import pandas as pd

# %%
data=pd.read_csv('insurance_pre.csv')

# %%
data1=pd.get_dummies(data,drop_first=True)

# %%
data1
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400     False        True
# 1      18  33.770         1   1725.55230      True       False
# 2      28  33.000         3   4449.46200      True       False
# 3      33  22.705         0  21984.47061      True       False
# 4      32  28.880         0   3866.85520      True       False
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830      True       False
# 1334   18  31.920         0   2205.98080     False       False
# 1335   18  36.850         0   1629.83350     False       False
# 1336   21  25.800         0   2007.94500     False       False
# 1337   61  29.070         0  29141.36030     False        True
#
# [1338 rows x 6 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
data1.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
independend=data1[['age', 'bmi', 'children', 'sex_male', 'smoker_yes']]

# %%
dependend=data1[['charges']]

# %%
independend
# Out:
#       age     bmi  children  sex_male  smoker_yes
# 0      19  27.900         0     False        True
# 1      18  33.770         1      True       False
# 2      28  33.000         3      True       False
# 3      33  22.705         0      True       False
# 4      32  28.880         0      True       False
# ...   ...     ...       ...       ...         ...
# 1333   50  30.970         3      True       False
# 1334   18  31.920         0     False       False
# 1335   18  36.850         0     False       False
# 1336   21  25.800         0     False       False
# 1337   61  29.070         0     False        True
#
# [1338 rows x 5 columns]

# %%
dependend
# Out:
#           charges
# 0     16884.92400
# 1      1725.55230
# 2      4449.46200
# 3     21984.47061
# 4      3866.85520
# ...           ...
# 1333  10600.54830
# 1334   2205.98080
# 1335   1629.83350
# 1336   2007.94500
# 1337  29141.36030
#
# [1338 rows x 1 columns]

# %%
X_train,X_test,Y_train,Y_test=train_test_split(independend,dependend,train_size=0.3,random_state=0)

# %%
#criterion{“squared_error”, “friedman_mse”, “absolute_error”, “poisson”}, default=”squared_error”
#splitter{“best”, “random”}, default=”best”
#max_featuresint, float or {“sqrt”, “log2”}, default=None

from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import GridSearchCV
grid_param={'criterion':['squared_error', 'friedman_mse', 'absolute_error', 'poisson'], 'splitter':['best', 'random'], 'max_features':['sqrt','log2']}
grid=GridSearchCV(DecisionTreeRegressor(),grid_param,refit=True,verbose=3,n_jobs=-1)
grid.fit(X_train,Y_train)
# Out:
# Fitting 5 folds for each of 16 candidates, totalling 80 fits
# GridSearchCV(estimator=DecisionTreeRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['squared_error', 'friedman_mse',
#                                        'absolute_error', 'poisson'],
#                          'max_features': ['sqrt', 'log2'],
#                          'splitter': ['best', 'random']},
#              verbose=3)

# %%
re=grid.cv_results_

# %%
grid.best_score_
# Out:
# 0.6445955224146644

# %%
grid.best_params_
# Out:
# {'criterion': 'friedman_mse', 'max_features': 'sqrt', 'splitter': 'best'}

# %%
table=pd.DataFrame.from_dict(re)

# %%
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.004337      0.000253         0.002372        0.000254
# 1        0.003930      0.000545         0.004085        0.002279
# 2        0.004117      0.000360         0.002532        0.000699
# 3        0.005793      0.002666         0.001520        0.001252
# 4        0.001793      0.002113         0.003651        0.004471
# 5        0.005999      0.004926         0.004827        0.004237
# 6        0.004006      0.003414         0.000802        0.001023
# 7        0.002463      0.002037         0.005069        0.004056
# 8        0.010102      0.002273         0.003252        0.001875
# 9        0.008044      0.004392         0.005073        0.002314
# 10       0.008213      0.003416         0.002890        0.000487
# 11       0.005119      0.000193         0.002989        0.001058
# 12       0.004706      0.001124         0.003271        0.001583
# 13       0.003705      0.000392         0.002508        0.000464
# 14       0.004486      0.000773         0.002309        0.000408
# 15       0.003588      0.000488         0.002410        0.001220
#
#    param_criterion param_max_features param_splitter  \
# 0    squared_error               sqrt           best
# 1    squared_error               sqrt         random
# 2    squared_error               log2           best
# 3    squared_error               log2         random
# 4     friedman_mse               sqrt           best
# 5     friedman_mse               sqrt         random
# 6     friedman_mse               log2           best
# 7     friedman_mse               log2         random
# 8   absolute_error               sqrt           best
# 9   absolute_error               sqrt         random
# 10  absolute_error               log2           best
# 11  absolute_error               log2         random
# 12         poisson               sqrt           best
# 13         poisson               sqrt         random
# 14         poisson               log2           best
# 15         poisson               log2         random
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'squared_error', 'max_features':...           0.624815
# 1   {'criterion': 'squared_error', 'max_features':...           0.560658
# 2   {'criterion': 'squared_error', 'max_features':...           0.455161
# 3   {'criterion': 'squared_error', 'max_features':...           0.426184
# 4   {'criterion': 'friedman_mse', 'max_features': ...           0.556203
# 5   {'criterion': 'friedman_mse', 'max_features': ...           0.313427
# 6   {'criterion': 'friedman_mse', 'max_features': ...           0.526614
# 7   {'criterion': 'friedman_mse', 'max_features': ...           0.483849
# 8   {'criterion': 'absolute_error', 'max_features'...           0.578251
# 9   {'criterion': 'absolute_error', 'max_features'...           0.144222
# 10  {'criterion': 'absolute_error', 'max_features'...           0.316054
# 11  {'criterion': 'absolute_error', 'max_features'...           0.474912
# 12  {'criterion': 'poisson', 'max_features': 'sqrt...           0.716196
# 13  {'criterion': 'poisson', 'max_features': 'sqrt...           0.461440
# 14  {'criterion': 'poisson', 'max_features': 'log2...           0.070143
# 15  {'criterion': 'poisson', 'max_features': 'log2...           0.360972
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.531378           0.025517           0.708897
# 1            0.685873           0.152365           0.531363
# 2            0.664838           0.138950           0.726838
# 3            0.535220          -0.261289           0.492177
# 4            0.703053           0.387861           0.731696
# 5            0.587380           0.338401           0.643294
# 6            0.529554           0.483134           0.582836
# 7            0.686438           0.469020           0.522309
# 8            0.626150           0.300028           0.472276
# 9            0.626721           0.354958           0.406122
# 10           0.635637           0.384906           0.616258
# 11           0.756523           0.347529           0.453385
# 12           0.622090          -0.159928           0.683903
# 13           0.623998           0.312942           0.677231
# 14           0.724193          -0.089765           0.602445
# 15           0.603849           0.246939           0.428955
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.790852         0.536292        0.269572                6
# 1            0.608968         0.507845        0.185272                8
# 2            0.540995         0.505356        0.206171                9
# 3            0.178321         0.274123        0.294851               16
# 4            0.844165         0.644596        0.157834                1
# 5            0.589236         0.494348        0.139209               11
# 6            0.639392         0.552306        0.053812                3
# 7            0.603892         0.553102        0.081452                2
# 8            0.715919         0.538525        0.142825                5
# 9            0.560403         0.418485        0.169063               14
# 10           0.549210         0.500413        0.127606               10
# 11           0.614539         0.529378        0.141886                7
# 12           0.457194         0.463891        0.324434               12
# 13           0.680571         0.551236        0.143349                4
# 14           0.745781         0.410559        0.350362               15
# 15           0.500402         0.428223        0.121195               13

# %%
age=float(input('Age:'))
bmi_input=float(input('BMI:'))
childeren=float(input('childeren:'))
sex=int(input('sex Male=0 or else'))
smoker=int(input('smoker Yes=0 else 1'))
# Out:
# Age: 22
# BMI: 34
# childeren: 2
# sex Male=0 or else 0
# smoker Yes=0 else 1 1

# %%
Future_predict=grid.predict([[age,bmi_input,childeren,sex,smoker]])
# Out:
# C:\Users\mojayara\AppData\Local\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(

# %%
print(Future_predict)
# Out:
# [36021.0112]
