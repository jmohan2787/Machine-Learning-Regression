# %%
import pandas as pd

# %%
data=pd.read_csv('insurance_pre.csv')

# %%
data1=pd.get_dummies(data,drop_first=True)

# %%
data1
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400     False        True
# 1      18  33.770         1   1725.55230      True       False
# 2      28  33.000         3   4449.46200      True       False
# 3      33  22.705         0  21984.47061      True       False
# 4      32  28.880         0   3866.85520      True       False
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830      True       False
# 1334   18  31.920         0   2205.98080     False       False
# 1335   18  36.850         0   1629.83350     False       False
# 1336   21  25.800         0   2007.94500     False       False
# 1337   61  29.070         0  29141.36030     False        True
#
# [1338 rows x 6 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
data1.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
independend=data1[['age', 'bmi', 'children', 'sex_male', 'smoker_yes']]

# %%
dependend=data1[['charges']]

# %%
independend
# Out:
#       age     bmi  children  sex_male  smoker_yes
# 0      19  27.900         0     False        True
# 1      18  33.770         1      True       False
# 2      28  33.000         3      True       False
# 3      33  22.705         0      True       False
# 4      32  28.880         0      True       False
# ...   ...     ...       ...       ...         ...
# 1333   50  30.970         3      True       False
# 1334   18  31.920         0     False       False
# 1335   18  36.850         0     False       False
# 1336   21  25.800         0     False       False
# 1337   61  29.070         0     False        True
#
# [1338 rows x 5 columns]

# %%
dependend
# Out:
#           charges
# 0     16884.92400
# 1      1725.55230
# 2      4449.46200
# 3     21984.47061
# 4      3866.85520
# ...           ...
# 1333  10600.54830
# 1334   2205.98080
# 1335   1629.83350
# 1336   2007.94500
# 1337  29141.36030
#
# [1338 rows x 1 columns]

# %%
X_train,X_test,Y_train,Y_test=train_test_split(independend,dependend,train_size=0.3,random_state=0)

# %%
#kernel{‘linear’, ‘poly’, ‘rbf’, ‘sigmoid’, ‘precomputed’} 
#gamma{‘scale’, ‘auto’}
#C=1.0
from sklearn.svm import SVR
from sklearn.model_selection import GridSearchCV
# params={'kernel':['linear', 'poly', 'rbf', 'sigmoid'],'C':[0.1,0.5,10,100],'gamma':['scale','auto']}?
param_grid = {'kernel':['rbf','linear'],
'C':[0.1],'gamma':['auto','scale']}
grid=GridSearchCV(SVR(),param_grid,refit=True,verbose=3,n_jobs=-1)
grid.fit(X_train,Y_train)
# Out:
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# C:\Users\mojayara\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1339: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# GridSearchCV(estimator=SVR(), n_jobs=-1,
#              param_grid={'C': [0.1], 'gamma': ['auto', 'scale'],
#                          'kernel': ['rbf', 'linear']},
#              verbose=3)

# %%
cv=grid.cv_results_

# %%
cv
# Out:
# {'mean_fit_time': array([0.03300433, 0.02359743, 0.0104888 , 0.00830364]),
#  'std_fit_time': array([0.00118665, 0.00972586, 0.00093395, 0.00219886]),
#  'mean_score_time': array([0.00818739, 0.0039084 , 0.00704722, 0.00259299]),
#  'std_score_time': array([0.00048811, 0.0005151 , 0.00037418, 0.00079547]),
#  'param_C': masked_array(data=[0.1, 0.1, 0.1, 0.1],
#               mask=[False, False, False, False],
#         fill_value=1e+20),
#  'param_gamma': masked_array(data=['auto', 'auto', 'scale', 'scale'],
#               mask=[False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'param_kernel': masked_array(data=['rbf', 'linear', 'rbf', 'linear'],
#               mask=[False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'params': [{'C': 0.1, 'gamma': 'auto', 'kernel': 'rbf'},
#   {'C': 0.1, 'gamma': 'auto', 'kernel': 'linear'},
#   {'C': 0.1, 'gamma': 'scale', 'kernel': 'rbf'},
#   {'C': 0.1, 'gamma': 'scale', 'kernel': 'linear'}],
#  'split0_test_score': array([-0.20036273, -0.35396322, -0.20043499, -0.35396322]),
#  'split1_test_score': array([-0.03417445, -0.00263443, -0.0341207 , -0.00263443]),
#  'split2_test_score': array([-0.07035017, -0.19806823, -0.07036788, -0.19806823]),
#  'split3_test_score': array([-0.23735067, -0.24284159, -0.23734409, -0.24284159]),
#  'split4_test_score': array([-0.07829486, -0.11607563, -0.07827564, -0.11607563]),
#  'mean_test_score': array([-0.12410658, -0.18271662, -0.12410866, -0.18271662]),
#  'std_test_score': array([0.07964355, 0.11836106, 0.07966748, 0.11836106]),
#  'rank_test_score': array([1, 3, 2, 3])}

# %%
grid.best_params_
# Out:
# {'C': 0.1, 'gamma': 'auto', 'kernel': 'rbf'}

# %%
grid.best_score_
# Out:
# -0.12410657821430644

# %%
table=pd.DataFrame.from_dict(cv)

# %%
table
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  param_C  \
# 0       0.033004      0.001187         0.008187        0.000488      0.1
# 1       0.023597      0.009726         0.003908        0.000515      0.1
# 2       0.010489      0.000934         0.007047        0.000374      0.1
# 3       0.008304      0.002199         0.002593        0.000795      0.1
#
#   param_gamma param_kernel                                            params  \
# 0        auto          rbf      {'C': 0.1, 'gamma': 'auto', 'kernel': 'rbf'}
# 1        auto       linear   {'C': 0.1, 'gamma': 'auto', 'kernel': 'linear'}
# 2       scale          rbf     {'C': 0.1, 'gamma': 'scale', 'kernel': 'rbf'}
# 3       scale       linear  {'C': 0.1, 'gamma': 'scale', 'kernel': 'linear'}
#
#    split0_test_score  split1_test_score  split2_test_score  split3_test_score  \
# 0          -0.200363          -0.034174          -0.070350          -0.237351
# 1          -0.353963          -0.002634          -0.198068          -0.242842
# 2          -0.200435          -0.034121          -0.070368          -0.237344
# 3          -0.353963          -0.002634          -0.198068          -0.242842
#
#    split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0          -0.078295        -0.124107        0.079644                1
# 1          -0.116076        -0.182717        0.118361                3
# 2          -0.078276        -0.124109        0.079667                2
# 3          -0.116076        -0.182717        0.118361                3

# %%
age=float(input('Age:'))
bmi_input=float(input('BMI:'))
childeren=float(input('childeren:'))
sex=int(input('sex Male=0 or else'))
smoker=int(input('smoker Yes=0 else 1'))
# Out:
# Age: 23
# BMI: 34
# childeren: 2
# sex Male=0 or else 0
# smoker Yes=0 else 1 1

# %%
Future_predict=grid.predict([[age,bmi_input,childeren,sex,smoker]])
# Out:
# C:\Users\mojayara\AppData\Local\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but SVR was fitted with feature names
#   warnings.warn(

# %%
Future_predict
# Out:
# array([10043.3881849])
